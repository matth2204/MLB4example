# %% [markdown]
# <a href="https://colab.research.google.com/github/matth2204/MLB4example/blob/main/mlb4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_wine

# %%
data = load_wine()
df = pd.DataFrame(data["data"], columns=data.feature_names)
df["target"] = data.target
df.dropna(inplace=True)
df
# Out:
#      alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 0      14.23        1.71  2.43  ...                          3.92   1065.0       0
# 1      13.20        1.78  2.14  ...                          3.40   1050.0       0
# 2      13.16        2.36  2.67  ...                          3.17   1185.0       0
# 3      14.37        1.95  2.50  ...                          3.45   1480.0       0
# 4      13.24        2.59  2.87  ...                          2.93    735.0       0
# ..       ...         ...   ...  ...                           ...      ...     ...
# 173    13.71        5.65  2.45  ...                          1.74    740.0       2
# 174    13.40        3.91  2.48  ...                          1.56    750.0       2
# 175    13.27        4.28  2.26  ...                          1.56    835.0       2
# 176    13.17        2.59  2.37  ...                          1.62    840.0       2
# ...

# %%
df["target"].value_counts()
# Out:
# target
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(df.iloc[:   ,    :4])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=["target"])
Y = df["target"]
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
y_train.shape
# Out:
# (133,)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=2)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
plot_tree(model, feature_names=x_train.columns)
# Out:
# [Text(0.5, 0.8333333333333334, 'proline <= 755.0\ngini = 0.662\nsamples = 133\nvalue = [49, 47, 37]'),
#  Text(0.25, 0.5, 'color_intensity <= 4.0\ngini = 0.509\nsamples = 80\nvalue = [2, 46, 32]'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 42\nvalue = [0, 42, 0]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.277\nsamples = 38\nvalue = [2, 4, 32]'),
#  Text(0.75, 0.5, 'flavanoids <= 1.605\ngini = 0.204\nsamples = 53\nvalue = [47, 1, 5]'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.278\nsamples = 6\nvalue = [0, 1, 5]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 47\nvalue = [47, 0, 0]')]

# %%
model.score(x_test, y_test)
# Out:
# 0.8
